# %%
import degree

lat = 30.260790137678466
lng = 120.11723778288173
_time = 20251129
print(degree.get_moonrise(lat, lng, time=_time))
print(degree.get_moonset(lat, lng, time=_time))
# Out:
# (datetime.datetime(2025, 11, 29, 12, 54, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800))), 1.658567801946212, 0.0036883823558015966)
# (datetime.datetime(2025, 11, 29, 0, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800))), 4.557278800473849, 0.0025564946784039947)
